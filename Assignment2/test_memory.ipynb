# %%
import jax.numpy as jnp
from joblib import Memory
import equinox as eqx

mem = Memory(".joblib_cache", verbose=10)


class Test(eqx.Module):
    arr_in: jnp.ndarray
    b: int = 0


Hell

# %%
@mem.cache
def test(arr_in, mod_in):
    print("Ran")
    return jnp.sum(arr_in) + mod_in.b


arr_in = jnp.array([1.0, 2.0, 3.0])
mod_in = Test(arr_in=arr_in, b=5)

arr_out = mem.cache(test)(arr_in, mod_in)
print(arr_out)


print("hello")

print(hash(test))
# Out:
# [Memory]11.4s, 0.2min   : Loading test from .joblib_cache/joblib/__main__--tmp-ipykernel-337492606/test/84dce847cf2113a20e3775e861dc9510
# ________________________________________________test cache loaded - 0.0s, 0.0min
# 11.0
# hello
