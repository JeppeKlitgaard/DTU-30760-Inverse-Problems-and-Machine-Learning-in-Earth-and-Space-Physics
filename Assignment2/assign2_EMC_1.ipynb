# %%
from common_setup import *

# for reloading submodules without restarting kernel
# %load_ext autoreload
# %autoreload 2
# Out:
# /home/jkl/Code/DTU-30760-Inverse-Problems-and-Machine-Learning-in-Earth-and-Space-Physics/Assignment2
# N_d=758
# N_sources=52
# N_receivers=235
# y ∈ [831.512, 846.79]
# x_ptp = 9.88930054051525
# N_x = 41
# N_y = 63
# N_x × N_y = 2583
# empirical_prior_mean=np.float64(0.08494846202002479)
# /home/jkl/Code/DTU-30760-Inverse-Problems-and-Machine-Learning-in-Earth-and-Space-Physics/.pixi/envs/cuda/lib/python3.14/site-packages/gstools/covmodel/tools.py:552: AttributeWarning: Dimension 2 is not appropriate for this model.
#   warnings.warn(
# Fit without convergence: Spherical(dim=2, var=8.24e-06, len_scale=4.71, nugget=8.24e-06)
# Fit without convergence and no nugget: Spherical(dim=2, var=9.86e-06, len_scale=4.48)
# Fit with gtol=1e-14: Spherical(dim=2, var=8.06e-06, len_scale=5.16, nugget=1.83e-06)
# ...
